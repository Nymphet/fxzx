# %%
from lxml import etree
from io import StringIO, BytesIO

# %%
# 开始一个新的课程的练习的时候, 点开始练习之后先空着提交一次，从提交时的 xhr 就可以找到答案。
#   因为每次是从题库里抽出几道题目考试，提交一次得到的答案可能不全,
#   如果最后得分不足以拿到积分, 就把新的答案也合并进来。
ans = []
ans += [{"questionId":"557629","score":"8.0","answerNo":"B"},{"questionId":"557626","score":"8.0","answerNo":"D"},{"questionId":"557628","score":"8.0","answerNo":"A"},{"questionId":"557625","score":"8.0","answerNo":"B"},{"questionId":"557627","score":"8.0","answerNo":"D"},{"questionId":"557639","score":"8.0","answerNo":"ABCD"},{"questionId":"557636","score":"8.0","answerNo":"ABD"},{"questionId":"557638","score":"8.0","answerNo":"ABCD"},{"questionId":"557635","score":"8.0","answerNo":"AB"},{"questionId":"557637","score":"8.0","answerNo":"ABCD"},{"questionId":"557649","score":"4.0","answerNo":"0"},{"questionId":"557646","score":"4.0","answerNo":"1"},{"questionId":"557648","score":"4.0","answerNo":"0"},{"questionId":"557645","score":"4.0","answerNo":"1"},{"questionId":"557647","score":"4.0","answerNo":"1"}]
ans += [{"questionId":"557629","score":"8.0","answerNo":"B"},{"questionId":"557628","score":"8.0","answerNo":"A"},{"questionId":"557625","score":"8.0","answerNo":"B"},{"questionId":"557626","score":"8.0","answerNo":"D"},{"questionId":"557627","score":"8.0","answerNo":"D"},{"questionId":"557637","score":"8.0","answerNo":"ABCD"},{"questionId":"557636","score":"8.0","answerNo":"ABD"},{"questionId":"557633","score":"8.0","answerNo":"ABCD"},{"questionId":"557634","score":"8.0","answerNo":"ABC"},{"questionId":"557635","score":"8.0","answerNo":"AB"},{"questionId":"557646","score":"4.0","answerNo":"1"},{"questionId":"557645","score":"4.0","answerNo":"1"},{"questionId":"557642","score":"4.0","answerNo":"1"},{"questionId":"557643","score":"4.0","answerNo":"1"},{"questionId":"557644","score":"4.0","answerNo":"0"}]
ans += [{"questionId":"557630","score":"8.0","answerNo":"C"},{"questionId":"557629","score":"8.0","answerNo":"B"},{"questionId":"557626","score":"8.0","answerNo":"D"},{"questionId":"557627","score":"8.0","answerNo":"D"},{"questionId":"557628","score":"8.0","answerNo":"A"},{"questionId":"557638","score":"8.0","answerNo":"ABCD"},{"questionId":"557637","score":"8.0","answerNo":"ABCD"},{"questionId":"557634","score":"8.0","answerNo":"ABC"},{"questionId":"557635","score":"8.0","answerNo":"AB"},{"questionId":"557636","score":"8.0","answerNo":"ABD"},{"questionId":"557646","score":"4.0","answerNo":"1"},{"questionId":"557645","score":"4.0","answerNo":"1"},{"questionId":"557642","score":"4.0","answerNo":"1"},{"questionId":"557643","score":"4.0","answerNo":"1"},{"questionId":"557644","score":"4.0","answerNo":"0"}]
ans += [{"questionId":"557627","score":"8.0","answerNo":"D"},{"questionId":"557623","score":"8.0","answerNo":"D"},{"questionId":"557625","score":"8.0","answerNo":"B"},{"questionId":"557626","score":"8.0","answerNo":"D"},{"questionId":"557624","score":"8.0","answerNo":"C"},{"questionId":"557639","score":"8.0","answerNo":"ABCD"},{"questionId":"557635","score":"8.0","answerNo":"AB"},{"questionId":"557637","score":"8.0","answerNo":"ABCD"},{"questionId":"557638","score":"8.0","answerNo":"ABCD"},{"questionId":"557636","score":"8.0","answerNo":"ABD"},{"questionId":"557648","score":"4.0","answerNo":"0"},{"questionId":"557644","score":"4.0","answerNo":"0"},{"questionId":"557646","score":"4.0","answerNo":"1"},{"questionId":"557647","score":"4.0","answerNo":"1"},{"questionId":"557645","score":"4.0","answerNo":"1"}]
ans += [{"questionId":"557629","score":"8.0","answerNo":"B"},{"questionId":"557628","score":"8.0","answerNo":"A"},{"questionId":"557625","score":"8.0","answerNo":"B"},{"questionId":"557626","score":"8.0","answerNo":"D"},{"questionId":"557627","score":"8.0","answerNo":"D"},{"questionId":"557640","score":"8.0","answerNo":"ABCD"},{"questionId":"557639","score":"8.0","answerNo":"ABCD"},{"questionId":"557636","score":"8.0","answerNo":"ABD"},{"questionId":"557637","score":"8.0","answerNo":"ABCD"},{"questionId":"557638","score":"8.0","answerNo":"ABCD"},{"questionId":"557649","score":"4.0","answerNo":"0"},{"questionId":"557648","score":"4.0","answerNo":"0"},{"questionId":"557645","score":"4.0","answerNo":"1"},{"questionId":"557646","score":"4.0","answerNo":"1"},{"questionId":"557647","score":"4.0","answerNo":"1"}]
ans += [{"questionId":"557627","score":"8.0","answerNo":"D"},{"questionId":"557623","score":"8.0","answerNo":"D"},{"questionId":"557624","score":"8.0","answerNo":"C"},{"questionId":"557625","score":"8.0","answerNo":"B"},{"questionId":"557626","score":"8.0","answerNo":"D"},{"questionId":"557637","score":"8.0","answerNo":"ABCD"},{"questionId":"557633","score":"8.0","answerNo":"ABCD"},{"questionId":"557634","score":"8.0","answerNo":"ABC"},{"questionId":"557635","score":"8.0","answerNo":"AB"},{"questionId":"557636","score":"8.0","answerNo":"ABD"},{"questionId":"557650","score":"4.0","answerNo":"0"},{"questionId":"557646","score":"4.0","answerNo":"1"},{"questionId":"557647","score":"4.0","answerNo":"1"},{"questionId":"557648","score":"4.0","answerNo":"0"},{"questionId":"557649","score":"4.0","answerNo":"0"}]


'''
得到答案之后重新开始练习。

复制页面下方答题卡部分的 html，从而提取每一题的顺序。
     也可以从 html 大概开头的位置有一个 hidden 元素里提取
     (写法宣在线的老哥还给专门留了个后门啊，看来很懂嘛)

反复刷同一个练习的话, 每次只需要改动下面这一行,然后重新
    运行整个 notebook ，生成的 js 脚本会自动复制到剪贴板
    在 chrome console 中粘贴运行即可。
'''

myhtml = '''

<div class="xtcontent clear">
		<ul id="ulindex"><li id="index_0" value="557624"><a id="img_1" href="javascript:sps.changeWenTi(0)">1</a></li><li id="index_1" value="557627"><a id="img_2" href="javascript:sps.changeWenTi(1)">2</a></li><li id="index_2" value="557626"><a id="img_3" href="javascript:sps.changeWenTi(2)">3</a></li><li id="index_3" value="557623"><a id="img_4" href="javascript:sps.changeWenTi(3)">4</a></li><li id="index_4" value="557625"><a id="img_5" href="javascript:sps.changeWenTi(4)">5</a></li><li id="index_5" value="557637"><a id="img_6" href="javascript:sps.changeWenTi(5)">6</a></li><li id="index_6" value="557640"><a id="img_7" href="javascript:sps.changeWenTi(6)">7</a></li><li id="index_7" value="557639"><a id="img_8" href="javascript:sps.changeWenTi(7)">8</a></li><li id="index_8" value="557636"><a id="img_9" href="javascript:sps.changeWenTi(8)">9</a></li><li id="index_9" value="557638"><a id="img_10" href="javascript:sps.changeWenTi(9)">10</a></li><li id="index_10" value="557645"><a id="img_11" href="javascript:sps.changeWenTi(10)">11</a></li><li id="index_11" value="557648"><a id="img_12" href="javascript:sps.changeWenTi(11)">12</a></li><li id="index_12" value="557647"><a id="img_13" href="javascript:sps.changeWenTi(12)">13</a></li><li id="index_13" value="557644"><a id="img_14" href="javascript:sps.changeWenTi(13)">14</a></li><li id="index_14" value="557646"><a id="img_15" href="javascript:sps.changeWenTi(14)">15</a></li></ul>
	
	</div>


'''
html = etree.HTML(myhtml)
seq = html.xpath('//*/li/@value')

# 从给定题目的 id 搜索答案
def find_answer(qid, ans):
    nomatch_flag = True
    for a in ans:
        if a["questionId"] == qid:
            return [c for c in a["answerNo"]]
    if nomatch_flag:
        print("// No Match Find For ", qid)
        return []

# 如果要手动提交答案，就需要输出正确顺序的选项，也就是按照打乱的顺序计算选项的新位置。
# 从 xhr 就可以得到各个问题的排序。
# perm = [{"itemNo":"B,C,A,D","questionId":"557627","score":"8.0","type":"1"},{"itemNo":"B,C,A,D","questionId":"557625","score":"8.0","type":"1"},{"itemNo":"D,B,A,C","questionId":"557626","score":"8.0","type":"1"},{"itemNo":"D,A,C,B","questionId":"557624","score":"8.0","type":"1"},{"itemNo":"A,D,B,C","questionId":"557623","score":"8.0","type":"1"},{"itemNo":"A,C,B,D","questionId":"557639","score":"8.0","type":"2"},{"itemNo":"C,A,D,B","questionId":"557637","score":"8.0","type":"2"},{"itemNo":"B,C,A,D","questionId":"557638","score":"8.0","type":"2"},{"itemNo":"D,C,B,A","questionId":"557636","score":"8.0","type":"2"},{"itemNo":"C,A,D,B","questionId":"557635","score":"8.0","type":"2"},{"itemNo":"A","questionId":"557648","score":"4.0","type":"3"},{"itemNo":"A","questionId":"557646","score":"4.0","type":"3"},{"itemNo":"A","questionId":"557647","score":"4.0","type":"3"},{"itemNo":"A","questionId":"557645","score":"4.0","type":"3"},{"itemNo":"A","questionId":"557644","score":"4.0","type":"3"}]

# aset = {}
# choice = ['A','B','C','D']
# for i in perm:
#     qid = i["questionId"]
#     a = find_answer(qid, ans)
#     newa = []
#     if i["type"] != "3":
#         for c in a:
#             n = i["itemNo"].split(',').index(c)
# #             print(n)
#             newa.append(choice[n])
#     elif i["type"] == "3":
#             newa = a.copy()
#     aset[qid] = newa

# for i in seq:
#     print(i, aset[str(i)])

# %%
# 如果不打算手动做题，准备自动做题，那么就不用对答案排序了，直接查看选
#   项的 'value' 属性就知道这个选项原本的位置了。
# 用 Python 脚本生成一个自动填空的 JS 脚本，在 Chrome console 中
#   运行即可完成全部答题。

# 最后需要手动点击提交

# The following code generates a js script which 
#    fills in the answer automatically. Run the 
#    generated js script in Chrome console.

# Single Choice and Judgement
sc_t = """

s = document.querySelectorAll("input[type=radio]")
ans = {ans}

for (i = 0; i < s.length; i++) {{ 
    if (ans.includes(s[i].value)) {{
        s[i].checked = true;
    }}
}}

// sleep fow a while to avoid miss
await new Promise(r => setTimeout(r, 500));

// This is how fxzx go to next question
sps.next()

// sleep fow a while to avoid miss
await new Promise(r => setTimeout(r, 200));

"""

# Multiple Choice
mc_t = """

s = document.querySelectorAll("input[type=checkbox]")
ans = {ans}

for (i = 0; i < s.length; i++) {{ 
    if (ans.includes(s[i].value)) {{
        s[i].checked = true;
    }}
}}

// sleep fow a while to avoid miss
await new Promise(r => setTimeout(r, 500));

// This is how fxzx go to next question
sps.next()

// sleep fow a while to avoid miss
await new Promise(r => setTimeout(r, 200));

"""

my_print_message = ""

def my_print(s):
    global my_print_message
#     print(s)
    my_print_message += s


for i in seq:
    a = find_answer(i, ans)
    if len(a) == 1: # Single choice or judgement
        if a[0] in ['A', 'B', 'C', 'D']:
            my_print('// Single Choice')
            my_print(sc_t.format(ans = a))
        elif a[0] in ['0', '1']:
            my_print('// Judgement')
            if a[0] == '0':
                my_print(sc_t.format(ans = "['B']"))
            else:
                my_print(sc_t.format(ans = "['A']"))
        else:
            my_print('// Unknown question type!')
    else:
        my_print('// Multiple Choice')
        my_print(mc_t.format(ans = a))


# print(my_print_message)

# %%
# copy generated js script to clipboard.
# because most people do not have pyperclip installed,
#  use the pyperclip that comes with pandas.

import pandas.io.clipboard as pyperclip
pyperclip.copy(my_print_message)
